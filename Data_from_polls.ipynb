# %%
import tabula
import pandas as pd
import requests 
import json
from pandas.io.json import json_normalize
import numpy as np
#BANK DANYCH LOKALNYCH

# %% [markdown]
# ### próba przerobienia pdfów

# %%
# Read pdf into DataFrame
#https://stackoverflow.com/questions/45457054/tabula-extract-tables-by-area-coordinates
#pobieranie danych dla diecezji
#https://docs.google.com/spreadsheets/d/1WHCrTZX2WJeYStcG58wh6y9Q58bwhGRG92iLxz4Paek/edit#gid=752560630
df = tabula.read_pdf("sondaze/K_157_11.PDF",
                     multiple_tables=True, 
                     pages=[4],
                     #stream = True
                     guess = True,  
                     #pandas_options={'header':True},
                     #area=(20, 40, 695, 589),
                     spreadsheet=True
                    )

# %%
df[0]
# Out:
#                                                     0  \
# 0   Na kandydata, której partii\rzamierza Pan(i) g...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                            Platforma Obywatelska RP
# 5                              Prawo i Sprawiedliwość
# 6                          Polskie Stronnictwo Ludowe
# 7                                       Ruch Palikota
# 8                       Sojusz Lewicy\rDemokratycznej
# 9                                                 NaN
# 10                                 Solidarna Polska**
# 11                          Polska Jest Najważniejsza
# 12            Nowa Prawica Janusza\rKorwin-Mikkego***
# 13                                                NaN
# 14                           Prawica Rzeczypospolitej
# 15                                Polska Partia Pracy
# 16                                               Inne
# 17                                  Trudno powiedzieć
# 18                                                 N=
# 19  * Podstawą procentowania są wszyscy ci, którzy...
#
#                                                     1        2         3  \
# 0   Odpowiedzi osób deklarujących wzięcie udziału\...      NaN       NaN
# 1                                            IV\r2011  V\r2011  VI\r2011
# 2                                                 NaN      NaN       NaN
# 3                                        w procentach      NaN       NaN
# 4                                                  31       37        34
# 5                                                  23       21        22
# 6                                                   5        4         5
# 7                                                   1        1         1
# 8                                                  12       12        11
# 9                                                 NaN      NaN       NaN
# 10                                                  -        -         -
# 11                                                  2        1         3
# 12                                                  1        1         0
# 13                                                NaN      NaN       NaN
# 14                                                  1        0         0
# 15                                                  0        0         0
# 16                                                  3        0         1
# 17                                                 18       18        19
# 18                                                679      689       640
# 19                                                NaN      NaN       NaN
#
#             4           5         6        7     8           9    10   11  \
# 0         NaN         NaN       NaN      NaN   NaN         NaN   NaN  NaN
# 1   VII\r2011  VIII\r2011  IX\r2011  X\r2011   NaN      Wyniki   NaN  NaN
# 2         NaN         NaN       NaN      NaN   NaN     wyborów  2011  NaN
# 3         NaN         NaN       NaN      NaN   NaN         NaN   NaN  NaN
# 4          38          36        37       34   NaN       39,18   NaN  NaN
# 5          17          20        20       20   NaN       29,89   NaN  NaN
# 6           4           4         6        6   NaN        8,36   NaN  NaN
# 7           1           1         2        7   NaN       10,02   NaN  NaN
# 8           9           8         7        9  8,24           7     5  NaN
# 9         NaN         NaN       NaN      NaN   NaN        8,24     7    5
# 10          -           -         -        -   NaN           -   NaN  NaN
# 11          0           0         1        1   NaN        2,19   NaN  NaN
# 12          0           0         -        -  1,06           1     1  NaN
# 13        NaN         NaN       NaN      NaN   NaN        1,06     1    1
# 14          0           0         -        -   NaN        0,24   NaN  NaN
# 15          0           0         0        1   NaN        0,55   NaN  NaN
# 16          0           0         1        1   NaN        0,26   NaN  NaN
# 17         27          26        26       22   NaN           -   NaN  NaN
# 18        591         619       627      694   NaN  15 050 027   NaN  NaN
# 19        NaN         NaN       NaN      NaN   NaN         NaN   NaN  NaN
#
#      12  13         14   15  16
# 0   NaN NaN        NaN  NaN NaN
# 1    XI NaN  XII\r2011  NaN NaN
# 2   NaN NaN        NaN  NaN NaN
# 3   NaN NaN        NaN  NaN NaN
# 4    42 NaN        NaN   43 NaN
# 5    21 NaN        NaN   21 NaN
# 6     7 NaN        NaN    7 NaN
# 7     9 NaN        NaN    6 NaN
# 8   NaN NaN        NaN  NaN NaN
# 9   NaN NaN        NaN  NaN NaN
# 10    - NaN        NaN    2 NaN
# 11    2 NaN        NaN    1 NaN
# 12  NaN NaN        NaN  NaN NaN
# 13  NaN NaN        NaN  NaN NaN
# 14    1 NaN        NaN    0 NaN
# 15    0 NaN        NaN    0 NaN
# 16    1 NaN        NaN    1 NaN
# 17    9 NaN        NaN   13 NaN
# 18  567 NaN        NaN  557 NaN
# 19  NaN NaN        NaN  NaN NaN
