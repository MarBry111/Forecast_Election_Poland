# %%
import tabula
import pandas as pd
import requests 
import json
from pandas.io.json import json_normalize
import numpy as np
#BANK DANYCH LOKALNYCH

# %% [markdown]
# ### pobieranie tabel

# %%
# Read pdf into DataFrame
#https://stackoverflow.com/questions/45457054/tabula-extract-tables-by-area-coordinates
#pobieranie danych dla diecezji
#https://docs.google.com/spreadsheets/d/1WHCrTZX2WJeYStcG58wh6y9Q58bwhGRG92iLxz4Paek/edit#gid=752560630
df = tabula.read_pdf("sondaze/dane_koscielne/Annuarium_Statisticum_2020_07.01.pdf",
                     multiple_tables=True, 
                     pages=[49],
                     #stream = True
                     guess = True,  
                     #pandas_options={'header':True},
                     #area=(20, 40, 695, 589),
                     spreadsheet=True
                    )

# %%
df[0][[0,1]]
# Out:
#                           0        1
# 0                  Diecezja  Parafie
# 1                  Diecezja  Parafie
# 2                       NaN      NaN
# 3                    Ogółem   10 551
# 4               białostocka      115
# 5          bielsko-żywiecka      212
# 6                  bydgoska      150
# 7             częstochowska      318
# 8              drohiczyńska       98
# 9                  elbląska      160
# 10                    ełcka      150
# 11                  gdańska      203
# 12                 gliwicka      159
# 13             gnieźnieńska      271
# 14                  kaliska      285
# 15                katowicka      322
# 16                 kielecka      307
# 17  koszalińsko-kołobrzeska      228
# 18                krakowska      468
# 19                 legnicka      244
# 20                 lubelska      279
# 21                łomżyńska      182
# 22                  łowicka      170
# 23                   łódzka      222
# 24                  opolska      399
# 25     Ordynariat Polowy WP      103
# 26               pelplińska      293
# 27                   płocka      251
# 28                poznańska      414
# 29                przemyska      398
# 30                 radomska      306
# 31               rzeszowska      247
# 32             sandomierska      246
# 33                siedlecka      248
# 34              sosnowiecka      163
# 35    szczecińsko-kamieńska      276
# 36                świdnicka      193
# 37                tarnowska      464
# 38                 toruńska      198
# 39                warmińska      262
# 40               warszawska      224
# 41        warszawsko-praska      185
# 42               włocławska      232
# 43               wrocławska      304
# 44     zamojsko-lubaczowska      188
# 45  zielonogórsko-gorzowska      272
# 46       Obrządki wschodnie      NaN
# 47     przemysko-warszawska       86
# 48       wrocławsko-gdańska       56
# 49                ormiańska       nd
